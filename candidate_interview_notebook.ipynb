# %% [markdown]
# # New Database System with Suspicious Data
#
# <hr>
#
# ##    - On a Sunday morning, your boss, Abdullah, asks you to pull data for salaries across all government agencies from a new database system that just got introduced.
#
# ##    - The new database system extends the functionality of an older database system, meaning both systems should contain the same data.
#
# ##    - As a diligient data scientist, you want to do a sanity check and pull data from both resources to validate the output.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##    Load Database Data (Note: Read GFS as a string):

# %% [markdown]
# In the old database, the columns are the following:
# - Agency: represents an agency code unique to each agency
# - GFS: a GFS is a code used to identify types of transactions, other economic flows, and stocks of assets and liabilities.
# - Amount: the amount paid
# - Payment Date: the date on which the payment was made

# %%
old_db_path = 'https://raw.githubusercontent.com/aldukhi/candidate-test/main/old_db.csv'
new_db_path = 'https://raw.githubusercontent.com/aldukhi/candidate-test/main/new_db.csv'

# %%
### Enter Solution Below ###

# %% [markdown]
# ##    You decide to do a random check testing whether the data in the two databases is consistent:
#
# ###    - Look into how much was spent _under_ GFS 213 in November, 2018 in the old database

# %%
### Enter Solution Below ###

# %% [markdown]
# ###    - Look into how much was spent _under_ GFS 213 in November, 2018 in the new database

# %%
### Enter Solution Below ###

# %% [markdown]
# ##    Looks like the numbers in the two databases are not consistent. Let us explore further by merging the two data frames.
#
# ###    Tip: Look into making the merging columns consistent before merging them

# %%
### Enter Solution Below ###

# %% [markdown]
# ###    - Aggregate the merged dataframe to show annual spending

# %%
### Enter Solution Below ###

# %% [markdown]
# ###    - How much is the difference between the two databases each year?

# %%
### Enter Solution Below ###

# %% [markdown]
# ##    We want to convey this anomaly to our stakeholders by visualizing it.
# ### - Plot a graph showing the annual spending recorded in both databases:

# %%
### Enter Solution Below ###
